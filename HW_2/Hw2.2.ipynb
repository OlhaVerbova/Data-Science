# %% [markdown]
# Частина друга: Аналіз файлів

# %% [markdown]
# Проведіть аналіз файлу 2017_jun_final.csv. Файл містить результати опитування розробників у червні 2017 року.

# %% [markdown]
# **1. Прочитайте файл 2017_jun_final.csv за допомогою методу read_csv**

# %%
# %matplotlib inline
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
jun_final = pd.read_csv('2017_jun_final - 2017_jun_final.csv')

# %% [markdown]
# **Прочитайте отриману таблицю, використовуючи метод head**

# %%
print(jun_final.head())
# Out:
#    N                    Посада Мова програмування Спеціалізація  \
# 0  1        Junior QA engineer                NaN     Manual QA
# 1  2        Junior QA engineer                NaN     Manual QA
# 2  3         Software Engineer            C#/.NET           NaN
# 3  4         Software Engineer         JavaScript           NaN
# 4  5  Senior Software Engineer         JavaScript           NaN
#
#   Загальний досвід роботи Досвід роботи на поточному місці  \
# 0                     0.5                              0.5
# 1         менше 3 місяців                  менше 3 місяців
# 2                       4                                1
# 3                       5                                4
# 4       10 і більше років                              0.5
#
#    Зарплата на місяць  Зміна зарплати за 12 місяців   Місто   Розмір компанії  \
# 0                 400                             0  Харків        до 10 осіб
# ...

# %%
jun_final['salary'].plot(kind='hist', bins=10, edgecolor='black', color='lightblue', alpha=0.7)
plt.axvline(jun_final['salary'].mean(), color='green', linestyle='--', label='Mean Salary')
plt.title('Distribution of Salaries')
plt.xlabel('Salary')
plt.ylabel('Frequency')
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title('Salary Distribution', fontsize=14)
plt.xlabel('Salary', fontsize=12)
plt.ylabel('Number of Juns', fontsize=12)
plt.grid(True)
plt.legend()

plt.show()

# %%
position = python_data['Посада'].value_counts()
position.plot(kind='bar', color='lightblue')
plt.title('Positions ')
plt.xlabel('Position')
plt.ylabel('Number of Employees')
plt.xticks(fontsize=15, rotation=30)
plt.yticks(fontsize=15)
plt.grid(True)
plt.show()

# %% [markdown]
# **Визначте розмір таблиці за допомогою методу shape**

# %%
сount_rows = jun_final.shape[0]
count_columns = jun_final.shape[1]

print("Number of rows:", сount_rows)
print("Number of columns:", count_columns)
# Out:
# Number of rows: 8704
# Number of columns: 25

# %% [markdown]
# **Визначте типи всіх стовпців за допомогою dataframe.dtypes**

# %%
print(jun_final.dtypes)
# Out:
# N                                     int64
# Посада                               object
# Мова програмування                   object
# Спеціалізація                        object
# Загальний досвід роботи              object
# Досвід роботи на поточному місці     object
# Зарплата на місяць                    int64
# Зміна зарплати за 12 місяців          int64
# Місто                                object
# Розмір компанії                      object
# Тип компанії                         object
# Стать                                object
# Вік                                   int64
# Освіта                               object
# Університет                          object
# Ще студент                             bool
# Рівень англійської                   object
# Предметна область                    object
# Дата заповнення                      object
# User.Agent                           object
# exp                                 float64
# ...

# %% [markdown]
# **Порахуйте, яка частка пропусків міститься в кожній колонці (використовуйте методи isnull та sum)**

# %%
missing_data = (jun_final.isnull().sum() / len(jun_final)) * 100
missing_data_with_percent = missing_data.map("{:.2f}%".format)

print("Percentage of empty data in the table")
print(missing_data_with_percent)
# Out:
# Percentage of empty data in the table
# N                                    0.00%
# Посада                               0.00%
# Мова програмування                  44.23%
# Спеціалізація                       82.94%
# Загальний досвід роботи              0.00%
# Досвід роботи на поточному місці     0.00%
# Зарплата на місяць                   0.00%
# Зміна зарплати за 12 місяців         0.00%
# Місто                                0.00%
# Розмір компанії                      0.00%
# Тип компанії                         0.00%
# Стать                                0.00%
# Вік                                  0.00%
# Освіта                               0.00%
# Університет                          4.11%
# Ще студент                           0.00%
# Рівень англійської                   0.00%
# Предметна область                    2.56%
# Дата заповнення                      0.00%
# User.Agent                           0.00%
# exp                                  0.00%
# ...

# %% [markdown]
# **Видаліть усі стовпці з пропусками, крім стовпця "Мова програмування"**

# %%
columns_to_drop = [col for col in jun_final.columns if col != 'Мова програмування' and jun_final[col].isnull().any()]
jun_final_cleaned = jun_final.drop(columns=columns_to_drop)
print(jun_final_cleaned)
# Out:
#          N                    Посада Мова програмування  \
# 0        1        Junior QA engineer                NaN
# 1        2        Junior QA engineer                NaN
# 2        3         Software Engineer            C#/.NET
# 3        4         Software Engineer         JavaScript
# 4        5  Senior Software Engineer         JavaScript
# ...    ...                       ...                ...
# 8699  8700               QA engineer                NaN
# 8700  8701                 Marketing                NaN
# 8701  8702  Junior Software Engineer         Ruby/Rails
# 8702  8703                 Team lead                NaN
# 8703  8704  Senior Software Engineer               Java
#
#      Загальний досвід роботи Досвід роботи на поточному місці  \
# 0                        0.5                              0.5
# 1            менше 3 місяців                  менше 3 місяців
# 2                          4                                1
# ...

# %% [markdown]
# **Знову порахуйте, яка частка пропусків міститься в кожній колонці і переконайтеся, що залишився тільки стовпець "Мова.програмування"**

# %%
missing_data = (jun_final_cleaned.isnull().sum() / len(jun_final)) * 100
missing_data_with_percent = missing_data.map("{:.2f}%".format)

print("Percentage of empty data in the table")
print(missing_data_with_percent)
# Out:
# Percentage of empty data in the table
# N                                    0.00%
# Посада                               0.00%
# Мова програмування                  44.23%
# Загальний досвід роботи              0.00%
# Досвід роботи на поточному місці     0.00%
# Зарплата на місяць                   0.00%
# Зміна зарплати за 12 місяців         0.00%
# Місто                                0.00%
# Розмір компанії                      0.00%
# Тип компанії                         0.00%
# Стать                                0.00%
# Вік                                  0.00%
# Освіта                               0.00%
# Ще студент                           0.00%
# Рівень англійської                   0.00%
# Дата заповнення                      0.00%
# User.Agent                           0.00%
# exp                                  0.00%
# current_job_exp                      0.00%
# salary                               0.00%
# dtype: object

# %% [markdown]
# **Видаліть усі рядки у вихідній таблиці за допомогою методу dropna**

# %%
jun_final_cleaned = jun_final.dropna()
print(jun_final_cleaned)
# Out:
# Empty DataFrame
# Columns: [N, Посада, Мова програмування, Спеціалізація, Загальний досвід роботи, Досвід роботи на поточному місці, Зарплата на місяць, Зміна зарплати за 12 місяців, Місто, Розмір компанії, Тип компанії, Стать, Вік, Освіта, Університет, Ще студент, Рівень англійської, Предметна область, Дата заповнення, User.Agent, exp, current_job_exp, salary, Валюта, cls]
# Index: []
#
# [0 rows x 25 columns]

# %% [markdown]
# **Визначте новий розмір таблиці за допомогою методу shape**

# %%
сount_rows = jun_final_cleaned.shape[0]
count_columns = jun_final_cleaned.shape[1]

print("Number of rows:", сount_rows)
print("Number of columns:", count_columns)
# Out:
# Number of rows: 0
# Number of columns: 25

# %% [markdown]
# **Створіть нову таблицю python_data, в якій будуть тільки рядки зі спеціалістами, які вказали мову програмування Python**

# %%
programming_language = 'Python'
python_data = jun_final[jun_final['Мова програмування'] == programming_language]

print(python_data)
# Out:
#          N                    Посада Мова програмування Спеціалізація  \
# 12      13         Software Engineer             Python           NaN
# 68      69         Software Engineer             Python           NaN
# 87      88  Junior Software Engineer             Python           NaN
# 114    115  Junior Software Engineer             Python           NaN
# 143    144  Junior Software Engineer             Python           NaN
# ...    ...                       ...                ...           ...
# 8546  8547         Software Engineer             Python           NaN
# 8625  8626         Software Engineer             Python           NaN
# 8635  8636  Senior Software Engineer             Python           NaN
# 8673  8674  Junior Software Engineer             Python           NaN
# 8695  8696         Software Engineer             Python           NaN
#
#      Загальний досвід роботи Досвід роботи на поточному місці  \
# 12                         1                  менше 3 місяців
# ...

# %%
company_size_counts = python_data['Розмір компанії'].value_counts()
company_size_counts.plot(kind='bar', color='lightgreen')
plt.title('Company Size ')
plt.xlabel('Company size')
plt.ylabel('Number of Employees')
plt.xticks(fontsize=15, rotation=30)
plt.yticks(fontsize=15)
plt.show()

# %% [markdown]
# **Визначте розмір таблиці python_data за допомогою методу shape**

# %%
сount_rows = python_data.shape[0]
count_columns = python_data.shape[1]

print("Number of rows:", сount_rows)
print("Number of columns:", count_columns)
# Out:
# Number of rows: 207
# Number of columns: 25

# %% [markdown]
# **Використовуючи метод groupby, виконайте групування за стовпчиком "Посада"**

# %%
python_data.groupby(['Посада'], as_index=False)

# %% [markdown]
# **Створіть новий DataFrame, де для згрупованих даних за стовпчиком "Посада", виконайте агрегацію даних за допомогою методу agg і знайдіть мінімальне та максимальне значення у стовпчику "Зарплата.в.місяць"**

# %%
min_max_salary = python_data.groupby(['Посада']).agg({'Зарплата на місяць': ['min', 'max']})
min_max_salary.columns = ['Min salary', 'Max salary']

print(min_max_salary)
# Out:
#                           Min salary  Max salary
# Посада
# Junior Software Engineer         100        1250
# Senior Software Engineer        1300        9200
# Software Engineer                500        5400
# System Architect                3000        5000
# Technical Lead                  1425        6200

# %% [markdown]
# **Створіть функцію fill_avg_salary, яка повертатиме середнє значення заробітної плати на місяць. Використовуйте її для методу apply та створіть новий стовпчик "avg"**

# %%
min_max_salary['avg'] = min_max_salary.apply(lambda row: (row['Min salary'] + row['Max salary']) / 2, axis=1)

print(min_max_salary)
# Out:
#                           Min salary  Max salary     avg
# Посада
# Junior Software Engineer         100        1250   675.0
# Senior Software Engineer        1300        9200  5250.0
# Software Engineer                500        5400  2950.0
# System Architect                3000        5000  4000.0
# Technical Lead                  1425        6200  3812.5

# %% [markdown]
# **Створіть описову статистику за допомогою методу describe для нового стовпчика.**

# %%
min_max_salary['avg'].describe()
# Out:
# count       5.000000
# mean     3337.500000
# std      1700.091909
# min       675.000000
# 25%      2950.000000
# 50%      3812.500000
# 75%      4000.000000
# max      5250.000000
# Name: avg, dtype: float64

# %% [markdown]
# **Збережіть отриману таблицю в CSV файл**

# %%
min_max_salary.to_csv('min_max_avg_salary.csv', index=False)
